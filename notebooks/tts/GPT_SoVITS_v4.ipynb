# %% [markdown]
# <a href="https://colab.research.google.com/github/STAR-bit-STAR/codex-/blob/main/notebooks/tts/GPT_SoVITS_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 一键运行 GPT-SoVITS-v4
#点击左侧运行按钮后，如果运行过程中遇到弹窗提醒，点击取消cancel即可
# !git clone https://huggingface.co/kevinwang676/GPT-SoVITS-v4.git
# %cd GPT-SoVITS-v4
# !pip install -r requirements.txt
# !export is_share=True && python webui.py zh_CN
# Out:
# fatal: destination path 'GPT-SoVITS-v4' already exists and is not an empty directory.
# /content/GPT-SoVITS-v4
# Ignoring onnxruntime: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring opencc: markers 'sys_platform != "linux"' don't match your environment
# ...
# /content/GPT-SoVITS-v4/webui.py:300: SyntaxWarning: invalid escape sequence '\d'
#   parts = re.split("(\d+)", s)
# Traceback (most recent call last):
#   File "/content/GPT-SoVITS-v4/webui.py", line 78, in <module>
#     from tools import my_utils
#   File "/content/GPT-SoVITS-v4/tools/my_utils.py", line 5, in <module>
#     import gradio as gr
#   File "/usr/local/lib/python3.12/dist-packages/gradio/__init__.py", line 3, in <module>
#     import gradio._simple_templates
#   File "/usr/local/lib/python3.12/dist-packages/gradio/_simple_templates/__init__.py", line 1, in <module>
#     from .simpledropdown import SimpleDropdown
# ...
